# %% [markdown]
# Sentiment Analysis (Google's word2vec package for sentiment analysis)
#
# https://www.kaggle.com/c/word2vec-nlp-tutorial/data
#
#
# The labeled data set consists of 50,000 IMDB movie reviews, specially selected for sentiment analysis. The sentiment of reviews is binary, meaning the IMDB rating < 5 results in a sentiment score of 0, and rating >=7 have a sentiment score of 1. No individual movie has more than 30 reviews. The 25,000 review labeled training set does not include any of the same movies as the 25,000 review test set. In addition, there are another 50,000 IMDB reviews provided without any rating labels.

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
tf.__version__
# Out:
# '2.2.0'

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/atulpatelDS/Data_Files/master/Bag_of_Words/word2vec_nlp/labeledTrainData.tsv.zip",
                      header=0,delimiter="\t",quoting=3)

# %%
dataset.shape
# Out:
# (25000, 3)

# %%
dataset.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
## Extract the review and sentiment
sentiment = dataset["sentiment"]
review = dataset["review"]

# %%
type(sentiment),type(review)
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
## Need to convert the type in list, becuase Kera Tokenizer use list as an input
sentiment = sentiment.tolist()
review = review.tolist()

# %%
type(sentiment),type(review)
# Out:
# (list, list)

# %%
## lets display the ant review data
review[3]
# Out:
# '"It must be assumed that those who praised this film (\\"the greatest filmed opera ever,\\" didn\'t I read somewhere?) either don\'t care for opera, don\'t care for Wagner, or don\'t care about anything except their desire to appear Cultured. Either as a representation of Wagner\'s swan-song, or as a movie, this strikes me as an unmitigated disaster, with a leaden reading of the score matched to a tricksy, lugubrious realisation of the text.<br /><br />It\'s questionable that people with ideas as to what an opera (or, for that matter, a play, especially one by Shakespeare) is \\"about\\" should be allowed anywhere near a theatre or film studio; Syberberg, very fashionably, but without the smallest justification from Wagner\'s text, decided that Parsifal is \\"about\\" bisexual integration, so that the title character, in the latter stages, transmutes into a kind of beatnik babe, though one who continues to sing high tenor -- few if any of the actors in the film are the singers, and we get a double dose of Armin Jordan, the conductor, who is seen as the face (but not heard as the voice) of Amfortas, and also appears monstrously in double exposure as a kind of Batonzilla or Conductor Who Ate Monsalvat during the playing of the Good Friday music -- in which, by the way, the transcendant loveliness of nature is represented by a scattering of shopworn and flaccid crocuses stuck in ill-laid turf, an expedient which baffles me. In the theatre we sometimes have to piece out such imperfections with our thoughts, but I can\'t think why Syberberg couldn\'t splice in, for Parsifal and Gurnemanz, mountain pasture as lush as was provided for Julie Andrews in Sound of Music...<br /><br />The sound is hard to endure, the high voices and the trumpets in particular possessing an aural glare that adds another sort of fatigue to our impatience with the uninspired conducting and paralytic unfolding of the ritual. Someone in another review mentioned the 1951 Bayreuth recording, and Knappertsbusch, though his tempi are often very slow, had what Jordan altogether lacks, a sense of pulse, a feeling for the ebb and flow of the music -- and, after half a century, the orchestral sound in that set, in modern pressings, is still superior to this film."'

# %%
## Now convert the Text into Number using Keras Tokenizer, we can also use the NLTK library
tokenizer = keras.preprocessing.text.Tokenizer(num_words=6000)
## Lets fit all the reviews
tokenizer.fit_on_texts(review)

# %%
## Lets display to total index or total unique words count
len(tokenizer.index_word)
# Out:
# 88582

# %%
## Lets convert Text into numbers using TFIDF
review_feature = tokenizer.texts_to_matrix(review,mode="tfidf")
review_feature.shape
## We are getting only 6000 outof 88582 because we used num_words = 6000 during tokenization
# Out:
# (25000, 6000)

# %%
type(review_feature)
# Out:
# numpy.ndarray

# %%
review_feature[0:1,:]
# Out:
# array([[0.        , 2.75042893, 2.34574918, ..., 0.        , 0.        ,
#         0.        ]])

# %%
## Also we need to convert the sentiment into numpy array
sentiment = np.array(sentiment)

# %%
type(sentiment)
# Out:
# numpy.ndarray

# %%
## Lets build the model usinf Fully Connected Dense neural network
model = keras.models.Sequential()
## Normalize the dataset
model.add(keras.layers.BatchNormalization(input_shape=(6000,)))

## Add dense layers
model.add(keras.layers.Dense(1000,activation="relu"))
model.add(keras.layers.Dropout(0.8))
model.add(keras.layers.Dense(500,activation="relu"))
model.add(keras.layers.Dropout(0.7))
model.add(keras.layers.Dense(300,activation="relu"))
model.add(keras.layers.Dropout(0.6))
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dropout(0.6))

# %%
## Add output layer
model.add(keras.layers.Dense(1,activation="sigmoid"))  ## Because we need only 1 output

# %%
## Compile the model
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
## Train the model
model.fit(x=review_feature,y=sentiment,validation_split=0.2,batch_size=32,epochs=30)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1554 - accuracy: 0.9508 - val_loss: 1.0481 - val_accuracy: 0.8624
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1365 - accuracy: 0.9569 - val_loss: 1.0723 - val_accuracy: 0.8496
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1388 - accuracy: 0.9597 - val_loss: 0.9907 - val_accuracy: 0.8528
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1331 - accuracy: 0.9588 - val_loss: 1.0594 - val_accuracy: 0.8596
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1207 - accuracy: 0.9622 - val_loss: 1.0805 - val_accuracy: 0.8576
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1093 - accuracy: 0.9663 - val_loss: 1.5372 - val_accuracy: 0.8562
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1202 - accuracy: 0.9632 - val_loss: 1.4141 - val_accuracy: 0.8544
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1054 - accuracy: 0.9677 - val_loss: 1.6039 - val_accuracy: 0.8540
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1077 - accuracy: 0.9671 - val_loss: 1.1372 - val_accuracy: 0.8564
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1104 - accuracy: 0.9674 - val_loss: 1.8879 - val_accuracy: 0.8552
# Epoch 11/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1037 - accuracy: 0.9690 - val_loss: 1.8765 - val_accuracy: 0.8568
# Epoch 12/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1032 - accuracy: 0.9704 - val_loss: 1.4182 - val_accuracy: 0.8570
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1005 - accuracy: 0.9715 - val_loss: 2.3318 - val_accuracy: 0.8526
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0987 - accuracy: 0.9699 - val_loss: 2.4046 - val_accuracy: 0.8550
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1194 - accuracy: 0.9672 - val_loss: 1.5241 - val_accuracy: 0.8532
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1016 - accuracy: 0.9701 - val_loss: 1.3963 - val_accuracy: 0.8608
# Epoch 17/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0895 - accuracy: 0.9739 - val_loss: 1.7716 - val_accuracy: 0.8534
# Epoch 18/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1131 - accuracy: 0.9704 - val_loss: 1.9978 - val_accuracy: 0.8522
# Epoch 19/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0882 - accuracy: 0.9755 - val_loss: 1.9292 - val_accuracy: 0.8514
# Epoch 20/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1075 - accuracy: 0.9718 - val_loss: 1.7448 - val_accuracy: 0.8552
# Epoch 21/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0927 - accuracy: 0.9735 - val_loss: 2.5051 - val_accuracy: 0.8518
# Epoch 22/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0986 - accuracy: 0.9736 - val_loss: 1.5187 - val_accuracy: 0.8566
# Epoch 23/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0907 - accuracy: 0.9757 - val_loss: 2.0480 - val_accuracy: 0.8558
# Epoch 24/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0892 - accuracy: 0.9762 - val_loss: 2.0637 - val_accuracy: 0.8578
# Epoch 25/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0860 - accuracy: 0.9766 - val_loss: 2.1062 - val_accuracy: 0.8568
# Epoch 26/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0837 - accuracy: 0.9761 - val_loss: 1.4159 - val_accuracy: 0.8520
# Epoch 27/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0874 - accuracy: 0.9756 - val_loss: 2.0713 - val_accuracy: 0.8552
# Epoch 28/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0907 - accuracy: 0.9753 - val_loss: 1.8525 - val_accuracy: 0.8558
# Epoch 29/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0816 - accuracy: 0.9767 - val_loss: 1.8609 - val_accuracy: 0.8596
# Epoch 30/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0816 - accuracy: 0.9763 - val_loss: 2.2212 - val_accuracy: 0.8624

# %% [markdown]
# There are overfitting in above accuracy so we need to tune our parameter. But accuracy still not good so we will try some other method to improve this.
